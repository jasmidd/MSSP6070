# %% [markdown]
# <a href="https://colab.research.google.com/github/jasmidd/MSSP6070/blob/main/Participation_Activity_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2.

# %%
spam = [2, 4, 6, 8, 10]
spam[2] = 'hello'
print(spam)
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# ---
#
#
#  3. a)

# %%
letters = ['a', 'b', 'c', 'd']
letters[int(int('3'*2)//11)]
# Out:
# 'd'

# %% [markdown]
# '3' * 2 => string 33
#
# int(33) => integer 33
#
# 33 // 11 => 3
#
# int(3) => integer 3
#
# letters[3] => value at index 3 => fourth value in the list => 'd'

# %% [markdown]
# 3. b)

# %%
letters = ['a',  'b',  'c', 'd']
letters[-1]
# Out:
# 'd'

# %% [markdown]
# letters[-1] => backward count one from the end of the list => last value in the list => 'd'

# %% [markdown]
# 3. c)

# %%
letters = ['a',  'b',  'c', 'd']
letters[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# letters[:2] => splice values starting at index 0 and ending before index 2 => splice first and second values in the list => ['a', 'b']

# %% [markdown]
# ---
#
#
#  4.

# %%
ex_tuple = tuple(letters)
print(ex_tuple)
# Out:
# ('a', 'b', 'c', 'd')

# %% [markdown]
# converts list into tuple

# %%
ex_list = list(ex_tuple)
print(ex_list)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# converts tuple into list

# %% [markdown]
# ---
#  5.

# %%
spam = ['apples', 'bananas', 'tofu', 'cats']
def comma_list(spam):
  return ", ".join(spam[:-1]) + ", and " + (spam[-1])
print(comma_list(spam))
# Out:
# apples, bananas, tofu, and cats
